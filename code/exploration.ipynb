# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
facilities = pd.read_csv(
    '../data/ODHF_v1.1/odhf_v1.1.csv', encoding='unicode_escape')

facilities.shape
# Out:
# (7033, 17)

# %%
facilities.head(3)
# Out:
#   index                           facility_name source_facility_type  \
# 0     1  Advanced Facial & Nasal Surgery Centre                other
# 1    10             Alberta Children's Hospital            pediatric
# 2   100                  Devon General Hospital              general
#
#                 odhf_facility_type                                   provider  \
# 0  Ambulatory health care services  Canadian Institute for Health Information
# 1                        Hospitals             Public Health Agency of Canada
# 2                        Hospitals             Public Health Agency of Canada
#
#   unit street_no street_name postal_code      city province  \
# 0  NaN       NaN         NaN     T5M 4G5  edmonton       ab
# 1  NaN        28   oki dr nw     T3B 6A8   calgary       ab
# 2  NaN       101   erie st s     T9G 1A6     devon       ab
#
#           source_format_str_address   CSDname     CSDuid  Pruid   latitude  \
# ...

# %%
facilities.groupby('province')['index'].count()
# Out:
# province
# ab     297
# bc    1316
# mb     160
# nb     170
# nl      81
# ns     178
# nt       6
# nu       3
# on    2695
# pe      95
# qc    1606
# sk     393
# yt      33
# Name: index, dtype: int64

# %%
beds = pd.read_excel(
    '../data/beds-staffed-and-in-operation-2020-2021-en.xlsx', sheet_name=2)

beds.shape
# Out:
# (634, 15)

# %%
beds.head(5)
# Out:
#   Province/territory Health region  \
# 0                 AB  Calgary Zone
# 1                 AB  Calgary Zone
# 2                 AB  Calgary Zone
# 3                 AB  Calgary Zone
# 4                 AB  Calgary Zone
#
#                                        Hospital name Type of hospital*  \
# 0                        Alberta Children’s Hospital             S-Ped
# 1                           Canmore General Hospital                 G
# 2  Claresholm Centre for Mental Health and Addict...             S-MHA
# 3                        Claresholm General Hospital                 G
# 4           Covenant Health Mineral Springs Hospital               G,E
#
#   Teaching status Intensive Care Obstetrics Pediatrics†  \
# 0        Teaching              —          —         124
# 1    Non-Teaching              —          —           —
# 2    Non-Teaching              —          —           —
# 3    Non-Teaching              —          —           —
# ...

# %%
wait_times = pd.read_excel(
    '../data/wait-times-priority-procedures-in-canada-data-tables-en.xlsx', sheet_name=2)

wait_times.shape
# Out:
# (13622, 8)

# %%
wait_times.head(5)
# Out:
#   Reporting level Province/territory Region        Indicator  \
# 0      Provincial            Alberta    NaN             CABG
# 1      Provincial            Alberta    NaN             CABG
# 2      Provincial            Alberta    NaN             CABG
# 3      Provincial            Alberta    NaN             CABG
# 4      Provincial            Alberta    NaN  Hip Replacement
#
#                 Metric Data year Unit of measurement  Indicator result
# 0  % meeting benchmark      2008          Proportion              99.0
# 1      50th percentile      2008                Days               7.0
# 2      90th percentile      2008                Days              83.0
# 3               Volume      2008     Number of cases               NaN
# 4  % meeting benchmark      2008          Proportion              77.0

# %%
wait_times = wait_times[wait_times['Data year'].isin([2020, 2021])]
